# %%
from __future__ import print_function
__author__ = '__fbb__'

import os 
import json
DFDATA = os.getenv("DFDATA")

# %pylab inline
DFDATA
# Out:
# Populating the interactive namespace from numpy and matplotlib
# '/data'

# %%
DFDATA = "/gws/open/NYCOpenData/nycopendata/data/"

# %%
''' Reads in a JSON file and manipulates it
'''
# Out:
# ' Reads in a JSON file and manipulates it\n'

# %% [markdown]
# ## Part 1. Waste data

# %%
# read in gas data
wasteData = json.load(open(DFDATA + "/../../../dataNYgov/OfficeAttorneyGeneral/2fni-raj8/rows.json", "r"))

# %%
# display the content
wasteData
# Out:
# {u'data': [[2128,
#    u'E2CF1D58-0D1D-4528-A0F6-66EBBBB6FC96',
#    2128,
#    1452900990,
#    u'708543',
#    1452901135,
#    u'708543',
#    None,
#    u'Albany Auto Parts',
#    u'222 Spruce Street',
#    None,
#    u'Albany',
#    u'NY',
#    u'?12210',
#    u'Albany',
#    u'4',
#    u'5184470970',
#    u'Ronald E Thompson Jr',
#    u'Private',
#    u'Vehicle Dismantling',
#    u'[7113308]',
#    u'Yes',
#    u'601449',
#    u'4723652',
#    u'4.1 - Address Matching',
#    None,
#    u'None',
#    u'?',
#    None,
#    None,
#    [u'{"address":"222 Spruce Street","city":"Albany","state":"NY","zip":"12210"}',
#     u'42.658617',
#     u'-73.762091',
#     None,
#     False]],
#   [1101,
#    u'02766518-7DF9-4744-A837-F6A53DB9439C',
#    1101,
#    1452900989,
#    u'708543',
#    1452901020,
#    u'708543',
#    None,
#    u'Albany Medical Center',
#    u'43 New Scotland Avenue',
#    None,
#    u'Albany',
#    u'NY',
#    u'?12208',
#    u'Albany',
#    u'4',
# ...

# %%
type(wasteData)
# Out:
# dict

# %%
# display the keys
wasteData.keys()
# Out:
# [u'meta', u'data']

# %%
# dispay the content of the element 'data'
wasteData['data']
# Out:
# [[2128,
#   u'E2CF1D58-0D1D-4528-A0F6-66EBBBB6FC96',
#   2128,
#   1452900990,
#   u'708543',
#   1452901135,
#   u'708543',
#   None,
#   u'Albany Auto Parts',
#   u'222 Spruce Street',
#   None,
#   u'Albany',
#   u'NY',
#   u'?12210',
#   u'Albany',
#   u'4',
#   u'5184470970',
#   u'Ronald E Thompson Jr',
#   u'Private',
#   u'Vehicle Dismantling',
#   u'[7113308]',
#   u'Yes',
#   u'601449',
#   u'4723652',
#   u'4.1 - Address Matching',
#   None,
#   u'None',
#   u'?',
#   None,
#   None,
#   [u'{"address":"222 Spruce Street","city":"Albany","state":"NY","zip":"12210"}',
#    u'42.658617',
#    u'-73.762091',
#    None,
#    False]],
#  [1101,
#   u'02766518-7DF9-4744-A837-F6A53DB9439C',
#   1101,
#   1452900989,
#   u'708543',
#   1452901020,
#   u'708543',
#   None,
#   u'Albany Medical Center',
#   u'43 New Scotland Avenue',
#   None,
#   u'Albany',
#   u'NY',
#   u'?12208',
#   u'Albany',
#   u'4',
#   u'5187832827',
#   u'Albany Medical Center',
#   u'Private',
# ...

# %%
type(wasteData['data'])
# Out:
# list

# %%
type(wasteData['data'][0])
# Out:
# list

# %%
wasteData['data'][0][:10]
# Out:
# [2128,
#  u'E2CF1D58-0D1D-4528-A0F6-66EBBBB6FC96',
#  2128,
#  1452900990,
#  u'708543',
#  1452901135,
#  u'708543',
#  None,
#  u'Albany Auto Parts',
#  u'222 Spruce Street']
